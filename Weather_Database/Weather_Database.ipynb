# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities= []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
    city_name = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city_name not in cities:
        cities.append(city_name)
#print(cities)
# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 732

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
query = "https://api.openweathermap.org/data/2.5/weather?"
appid=weather_api_key

url = query+"&units=Imperial&appid="+appid

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})            
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jalu
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | cayenne
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | yellowknife
# Processing Record 6 of Set 1 | mahibadhoo
# Processing Record 7 of Set 1 | senno
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | ambulu
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | sao filipe
# Processing Record 12 of Set 1 | harper
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | constitucion
# Processing Record 18 of Set 1 | konongo
# Processing Record 19 of Set 1 | chake chake
# Processing Record 20 of Set 1 | ozernovskiy
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | calatayud
# Processing Record 23 of Set 1 | angoche
# Processing Record 24 of Set 1 | luderitz
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | belyy yar
# Processing Record 27 of Set 1 | jinka
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | najran
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | buinsk
# Processing Record 34 of Set 1 | saint george
# Processing Record 35 of Set 1 | galle
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | emba
# Processing Record 38 of Set 1 | new norfolk
# Processing Record 39 of Set 1 | sangar
# Processing Record 40 of Set 1 | magnolia
# Processing Record 41 of Set 1 | calamar
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | kawalu
# Processing Record 44 of Set 1 | dovers
# Processing Record 45 of Set 1 | acapulco
# Processing Record 46 of Set 1 | ozerna
# Processing Record 47 of Set 1 | portland
# Processing Record 48 of Set 1 | itaituba
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | flin flon
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | bubaque
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | harboore
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | gandajika
# Processing Record 10 of Set 2 | baykit
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | srednekolymsk
# Processing Record 13 of Set 2 | khandyga
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | san quintin
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | rikitea
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | cheremukhovo
# Processing Record 24 of Set 2 | gemena
# Processing Record 25 of Set 2 | maracaibo
# Processing Record 26 of Set 2 | vila do maio
# Processing Record 27 of Set 2 | dabeiba
# Processing Record 28 of Set 2 | nelson bay
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | yarada
# Processing Record 32 of Set 2 | atuona
# Processing Record 33 of Set 2 | jablah
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | aksarka
# Processing Record 37 of Set 2 | san bartolome de tirajana
# Processing Record 38 of Set 2 | gubbio
# Processing Record 39 of Set 2 | steamboat springs
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | nanortalik
# Processing Record 42 of Set 2 | bredasdorp
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | axim
# Processing Record 46 of Set 2 | port hedland
# Processing Record 47 of Set 2 | mataura
# Processing Record 48 of Set 2 | rioja
# Processing Record 49 of Set 2 | boddam
# Processing Record 50 of Set 2 | souillac
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | half moon bay
# Processing Record 6 of Set 3 | mount gambier
# Processing Record 7 of Set 3 | luanda
# Processing Record 8 of Set 3 | jaru
# Processing Record 9 of Set 3 | ulladulla
# Processing Record 10 of Set 3 | namikupa
# Processing Record 11 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 12 of Set 3 | bad hersfeld
# Processing Record 13 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 3 | saldanha
# Processing Record 16 of Set 3 | cockburn town
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | belmonte
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | general roca
# Processing Record 21 of Set 3 | mugumu
# Processing Record 22 of Set 3 | bandarbeyla
# Processing Record 23 of Set 3 | hovd
# Processing Record 24 of Set 3 | santa cruz
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | maniitsoq
# Processing Record 27 of Set 3 | zyryanka
# Processing Record 28 of Set 3 | banjar
# Processing Record 29 of Set 3 | tacoronte
# Processing Record 30 of Set 3 | diphu
# Processing Record 31 of Set 3 | roald
# Processing Record 32 of Set 3 | ostrovnoy
# Processing Record 33 of Set 3 | te anau
# Processing Record 34 of Set 3 | walvis bay
# Processing Record 35 of Set 3 | fare
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | peleduy
# Processing Record 38 of Set 3 | mecca
# Processing Record 39 of Set 3 | salalah
# Processing Record 40 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 3 | camacha
# Processing Record 42 of Set 3 | nome
# Processing Record 43 of Set 3 | rocha
# Processing Record 44 of Set 3 | visnes
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | natchez
# Processing Record 48 of Set 3 | nortelandia
# Processing Record 49 of Set 3 | chuy
# Processing Record 50 of Set 3 | labuhan
# Processing Record 1 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | ambovombe
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 4 | dunedin
# Processing Record 6 of Set 4 | guarapari
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | alyangula
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | narasannapeta
# Processing Record 11 of Set 4 | alice springs
# Processing Record 12 of Set 4 | vorotynets
# Processing Record 13 of Set 4 | coquimbo
# Processing Record 14 of Set 4 | limbang
# Processing Record 15 of Set 4 | san policarpo
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | lichtenburg
# Processing Record 20 of Set 4 | cap malheureux
# Processing Record 21 of Set 4 | sioux lookout
# Processing Record 22 of Set 4 | coroata
# Processing Record 23 of Set 4 | qaanaaq
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | ahipara
# Processing Record 26 of Set 4 | qaqortoq
# Processing Record 27 of Set 4 | bathsheba
# Processing Record 28 of Set 4 | barrow
# Processing Record 29 of Set 4 | kondinskoye
# Processing Record 30 of Set 4 | semnan
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | barcelos
# Processing Record 33 of Set 4 | vanimo
# Processing Record 34 of Set 4 | juneau
# Processing Record 35 of Set 4 | mareeba
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | kupang
# Processing Record 38 of Set 4 | sunagawa
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | baker city
# Processing Record 41 of Set 4 | nabire
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | dikson
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | eloy
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 4 | marawi
# Processing Record 49 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 5 | leningradskiy
# Processing Record 2 of Set 5 | jinja
# Processing Record 3 of Set 5 | tuktoyaktuk
# Processing Record 4 of Set 5 | santa cruz del sur
# Processing Record 5 of Set 5 | abu kamal
# Processing Record 6 of Set 5 | la palma
# Processing Record 7 of Set 5 | lavrentiya
# Processing Record 8 of Set 5 | tazmalt
# Processing Record 9 of Set 5 | qasigiannguit
# Processing Record 10 of Set 5 | vaitape
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | ust-ishim
# Processing Record 13 of Set 5 | wiarton
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | ciudad bolivar
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | south venice
# Processing Record 18 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | dodoma
# Processing Record 21 of Set 5 | aklavik
# Processing Record 22 of Set 5 | mount darwin
# Processing Record 23 of Set 5 | nadym
# Processing Record 24 of Set 5 | avera
# Processing Record 25 of Set 5 | aykhal
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | upernavik
# Processing Record 28 of Set 5 | broome
# Processing Record 29 of Set 5 | la ronge
# Processing Record 30 of Set 5 | yasnyy
# Processing Record 31 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 5 | ao luk
# City not found. Skipping...
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 5 | bachaquero
# Processing Record 36 of Set 5 | kaitangata
# Processing Record 37 of Set 5 | otane
# Processing Record 38 of Set 5 | port lincoln
# Processing Record 39 of Set 5 | takoradi
# Processing Record 40 of Set 5 | kununurra
# Processing Record 41 of Set 5 | khatanga
# Processing Record 42 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | raymond
# Processing Record 45 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 5 | kharagpur
# Processing Record 47 of Set 5 | anloga
# Processing Record 48 of Set 5 | laguna
# Processing Record 49 of Set 5 | pindiga
# Processing Record 50 of Set 5 | jiuquan
# Processing Record 1 of Set 6 | vagur
# Processing Record 2 of Set 6 | alim
# Processing Record 3 of Set 6 | katherine
# Processing Record 4 of Set 6 | bolobo
# Processing Record 5 of Set 6 | minab
# Processing Record 6 of Set 6 | dire
# Processing Record 7 of Set 6 | xinqing
# Processing Record 8 of Set 6 | lagoa
# Processing Record 9 of Set 6 | lasa
# Processing Record 10 of Set 6 | antsohihy
# Processing Record 11 of Set 6 | elverum
# Processing Record 12 of Set 6 | delta del tigre
# Processing Record 13 of Set 6 | chadiza
# Processing Record 14 of Set 6 | lakes entrance
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 6 | lagos
# Processing Record 18 of Set 6 | dakar
# Processing Record 19 of Set 6 | zhengjiatun
# Processing Record 20 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 6 | starodub
# Processing Record 22 of Set 6 | diffa
# Processing Record 23 of Set 6 | zhigansk
# Processing Record 24 of Set 6 | mar del plata
# Processing Record 25 of Set 6 | beloha
# Processing Record 26 of Set 6 | sur
# Processing Record 27 of Set 6 | urucui
# Processing Record 28 of Set 6 | erdenet
# Processing Record 29 of Set 6 | santa ana
# Processing Record 30 of Set 6 | ponta delgada
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | huilong
# Processing Record 33 of Set 6 | ternate
# Processing Record 34 of Set 6 | seymchan
# Processing Record 35 of Set 6 | kanpur
# Processing Record 36 of Set 6 | almaznyy
# Processing Record 37 of Set 6 | fairbanks
# Processing Record 38 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 39 of Set 6 | mangaratiba
# Processing Record 40 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 6 | nhulunbuy
# Processing Record 42 of Set 6 | kavieng
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | swamimalai
# Processing Record 45 of Set 6 | honggang
# Processing Record 46 of Set 6 | diamantino
# Processing Record 47 of Set 6 | jacareacanga
# Processing Record 48 of Set 6 | morwa
# Processing Record 49 of Set 6 | sumbe
# Processing Record 50 of Set 6 | ambilobe
# Processing Record 1 of Set 7 | ion corvin
# Processing Record 2 of Set 7 | lircay
# Processing Record 3 of Set 7 | itarema
# Processing Record 4 of Set 7 | norman wells
# Processing Record 5 of Set 7 | hualmay
# Processing Record 6 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 7 of Set 7 | zverinogolovskoye
# Processing Record 8 of Set 7 | taoudenni
# Processing Record 9 of Set 7 | chara
# Processing Record 10 of Set 7 | dembi dolo
# Processing Record 11 of Set 7 | esso
# Processing Record 12 of Set 7 | umm kaddadah
# Processing Record 13 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 14 of Set 7 | sobolevo
# Processing Record 15 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 7 | thompson
# Processing Record 17 of Set 7 | saint anthony
# Processing Record 18 of Set 7 | havre-saint-pierre
# Processing Record 19 of Set 7 | noumea
# Processing Record 20 of Set 7 | blythe
# Processing Record 21 of Set 7 | merauke
# Processing Record 22 of Set 7 | zatoka
# Processing Record 23 of Set 7 | mgandu
# Processing Record 24 of Set 7 | richards bay
# Processing Record 25 of Set 7 | moyamba
# Processing Record 26 of Set 7 | san patricio
# Processing Record 27 of Set 7 | umm lajj
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | ihosy
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | vao
# Processing Record 32 of Set 7 | weligama
# Processing Record 33 of Set 7 | stornoway
# Processing Record 34 of Set 7 | sijunjung
# Processing Record 35 of Set 7 | okhotsk
# Processing Record 36 of Set 7 | camacupa
# Processing Record 37 of Set 7 | bengkulu
# Processing Record 38 of Set 7 | gien
# Processing Record 39 of Set 7 | mwene-ditu
# Processing Record 40 of Set 7 | devgarh
# Processing Record 41 of Set 7 | muscat
# Processing Record 42 of Set 7 | esna
# Processing Record 43 of Set 7 | sibolga
# Processing Record 44 of Set 7 | esperance
# Processing Record 45 of Set 7 | sayyan
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | tura
# Processing Record 49 of Set 7 | batemans bay
# Processing Record 50 of Set 7 | husavik
# Processing Record 1 of Set 8 | mayor pablo lagerenza
# Processing Record 2 of Set 8 | assiniboia
# Processing Record 3 of Set 8 | peniche
# Processing Record 4 of Set 8 | gorey
# Processing Record 5 of Set 8 | olyka
# Processing Record 6 of Set 8 | rivera
# Processing Record 7 of Set 8 | sola
# Processing Record 8 of Set 8 | yenagoa
# Processing Record 9 of Set 8 | kayerkan
# Processing Record 10 of Set 8 | ivanjica
# Processing Record 11 of Set 8 | obo
# Processing Record 12 of Set 8 | longkou
# Processing Record 13 of Set 8 | show low
# Processing Record 14 of Set 8 | turukhansk
# Processing Record 15 of Set 8 | cabra
# Processing Record 16 of Set 8 | namibe
# Processing Record 17 of Set 8 | lyubim
# Processing Record 18 of Set 8 | alta floresta
# Processing Record 19 of Set 8 | azul
# Processing Record 20 of Set 8 | havelock
# Processing Record 21 of Set 8 | porto belo
# Processing Record 22 of Set 8 | ayan
# Processing Record 23 of Set 8 | sao jose da coroa grande
# Processing Record 24 of Set 8 | athabasca
# Processing Record 25 of Set 8 | haldwani
# Processing Record 26 of Set 8 | the valley
# Processing Record 27 of Set 8 | tangamandapio
# City not found. Skipping...
# Processing Record 28 of Set 8 | rawson
# Processing Record 29 of Set 8 | alekseyevsk
# Processing Record 30 of Set 8 | amberley
# Processing Record 31 of Set 8 | skibbereen
# Processing Record 32 of Set 8 | mancio lima
# Processing Record 33 of Set 8 | zaysan
# Processing Record 34 of Set 8 | sassandra
# Processing Record 35 of Set 8 | ca mau
# Processing Record 36 of Set 8 | severo-kurilsk
# Processing Record 37 of Set 8 | yerbogachen
# Processing Record 38 of Set 8 | revelstoke
# Processing Record 39 of Set 8 | cherskiy
# Processing Record 40 of Set 8 | naze
# Processing Record 41 of Set 8 | quelimane
# Processing Record 42 of Set 8 | sinnamary
# Processing Record 43 of Set 8 | owando
# Processing Record 44 of Set 8 | manono
# Processing Record 45 of Set 8 | zhezkazgan
# Processing Record 46 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 47 of Set 8 | susurluk
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | burnie
# Processing Record 50 of Set 8 | sao jose de ribamar
# Processing Record 1 of Set 9 | karasjok
# Processing Record 2 of Set 9 | sao joao da barra
# Processing Record 3 of Set 9 | tchibanga
# Processing Record 4 of Set 9 | roma
# Processing Record 5 of Set 9 | nishihara
# Processing Record 6 of Set 9 | tiksi
# Processing Record 7 of Set 9 | toora-khem
# Processing Record 8 of Set 9 | linxia
# Processing Record 9 of Set 9 | gijon
# Processing Record 10 of Set 9 | lianzhou
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | mattru
# Processing Record 13 of Set 9 | jeremie
# Processing Record 14 of Set 9 | urumqi
# Processing Record 15 of Set 9 | todos santos
# Processing Record 16 of Set 9 | dicabisagan
# Processing Record 17 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 9 | flinders
# Processing Record 19 of Set 9 | puerto escondido
# Processing Record 20 of Set 9 | kamaishi
# Processing Record 21 of Set 9 | grand forks
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | ziarat
# Processing Record 24 of Set 9 | sabinas hidalgo
# Processing Record 25 of Set 9 | vestmannaeyjar
# Processing Record 26 of Set 9 | altamira
# Processing Record 27 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 9 | arraial do cabo
# Processing Record 29 of Set 9 | ust-kuyga
# Processing Record 30 of Set 9 | coahuayana
# Processing Record 31 of Set 9 | chimoio
# Processing Record 32 of Set 9 | seoul
# Processing Record 33 of Set 9 | sitka
# Processing Record 34 of Set 9 | pingliang
# Processing Record 35 of Set 9 | nalbari
# Processing Record 36 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 9 | pangody
# Processing Record 38 of Set 9 | las cruces
# Processing Record 39 of Set 9 | lao cai
# Processing Record 40 of Set 9 | batagay-alyta
# Processing Record 41 of Set 9 | garissa
# Processing Record 42 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 9 | teknaf
# Processing Record 44 of Set 9 | makakilo city
# Processing Record 45 of Set 9 | fort-de-france
# Processing Record 46 of Set 9 | fort nelson
# Processing Record 47 of Set 9 | kushmurun
# Processing Record 48 of Set 9 | sao gabriel da cachoeira
# Processing Record 49 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 9 | goderich
# Processing Record 1 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 10 | nantucket
# Processing Record 3 of Set 10 | saint-francois
# Processing Record 4 of Set 10 | rundu
# Processing Record 5 of Set 10 | darnah
# Processing Record 6 of Set 10 | samarai
# Processing Record 7 of Set 10 | longyearbyen
# Processing Record 8 of Set 10 | berlevag
# Processing Record 9 of Set 10 | sterling
# Processing Record 10 of Set 10 | turki
# Processing Record 11 of Set 10 | thinadhoo
# Processing Record 12 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 10 | campohermoso
# Processing Record 14 of Set 10 | kingston
# Processing Record 15 of Set 10 | tiznit
# Processing Record 16 of Set 10 | copiapo
# Processing Record 17 of Set 10 | surt
# Processing Record 18 of Set 10 | sharya
# Processing Record 19 of Set 10 | guiratinga
# Processing Record 20 of Set 10 | porohy
# Processing Record 21 of Set 10 | clovis
# Processing Record 22 of Set 10 | sohag
# Processing Record 23 of Set 10 | amga
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | svetlogorsk
# Processing Record 26 of Set 10 | bayeux
# Processing Record 27 of Set 10 | kiama
# Processing Record 28 of Set 10 | mayo
# Processing Record 29 of Set 10 | poronaysk
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | udachnyy
# Processing Record 33 of Set 10 | mikhaylovka
# Processing Record 34 of Set 10 | karera
# Processing Record 35 of Set 10 | dandong
# Processing Record 36 of Set 10 | parfino
# Processing Record 37 of Set 10 | kargasok
# Processing Record 38 of Set 10 | zig
# Processing Record 39 of Set 10 | machachi
# Processing Record 40 of Set 10 | ondjiva
# Processing Record 41 of Set 10 | adrar
# Processing Record 42 of Set 10 | namatanai
# Processing Record 43 of Set 10 | dukat
# Processing Record 44 of Set 10 | muhammadabad
# Processing Record 45 of Set 10 | staryy nadym
# Processing Record 46 of Set 10 | stara synyava
# Processing Record 47 of Set 10 | mae ramat
# Processing Record 48 of Set 10 | san cristobal
# Processing Record 49 of Set 10 | pringsewu
# Processing Record 50 of Set 10 | arequipa
# Processing Record 1 of Set 11 | naklo nad notecia
# Processing Record 2 of Set 11 | riyadh
# Processing Record 3 of Set 11 | mitzic
# Processing Record 4 of Set 11 | antofagasta
# Processing Record 5 of Set 11 | muroto
# Processing Record 6 of Set 11 | machico
# Processing Record 7 of Set 11 | panguna
# Processing Record 8 of Set 11 | botwood
# Processing Record 9 of Set 11 | willmar
# Processing Record 10 of Set 11 | gigmoto
# Processing Record 11 of Set 11 | faya
# Processing Record 12 of Set 11 | kashary
# Processing Record 13 of Set 11 | karacabey
# Processing Record 14 of Set 11 | saryg-sep
# Processing Record 15 of Set 11 | shangzhi
# Processing Record 16 of Set 11 | los llanos de aridane
# Processing Record 17 of Set 11 | valcourt
# Processing Record 18 of Set 11 | burns lake
# Processing Record 19 of Set 11 | acarau
# Processing Record 20 of Set 11 | roebourne
# Processing Record 21 of Set 11 | ilulissat
# Processing Record 22 of Set 11 | manggar
# Processing Record 23 of Set 11 | ajdabiya
# Processing Record 24 of Set 11 | buochs
# Processing Record 25 of Set 11 | sabang
# Processing Record 26 of Set 11 | bonthe
# Processing Record 27 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | bardiyah
# Processing Record 30 of Set 11 | naryan-mar
# Processing Record 31 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 11 | fengrun
# Processing Record 33 of Set 11 | wilmington
# Processing Record 34 of Set 11 | tucupita
# Processing Record 35 of Set 11 | talara
# Processing Record 36 of Set 11 | clyde river
# Processing Record 37 of Set 11 | yei
# Processing Record 38 of Set 11 | serenje
# Processing Record 39 of Set 11 | lakewood
# Processing Record 40 of Set 11 | novo aripuana
# Processing Record 41 of Set 11 | beringovskiy
# Processing Record 42 of Set 11 | ketchikan
# Processing Record 43 of Set 11 | atasu
# Processing Record 44 of Set 11 | werda
# Processing Record 45 of Set 11 | feijo
# Processing Record 46 of Set 11 | puerto narino
# Processing Record 47 of Set 11 | caravelas
# Processing Record 48 of Set 11 | kenai
# Processing Record 49 of Set 11 | haines junction
# Processing Record 50 of Set 11 | padang
# Processing Record 1 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 2 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 12 | tuy hoa
# Processing Record 4 of Set 12 | sept-iles
# Processing Record 5 of Set 12 | yulara
# Processing Record 6 of Set 12 | salinopolis
# Processing Record 7 of Set 12 | sunrise manor
# Processing Record 8 of Set 12 | mirnyy
# Processing Record 9 of Set 12 | encruzilhada
# Processing Record 10 of Set 12 | buala
# Processing Record 11 of Set 12 | ossora
# Processing Record 12 of Set 12 | henties bay
# Processing Record 13 of Set 12 | yarega
# Processing Record 14 of Set 12 | bindi
# Processing Record 15 of Set 12 | veraval
# Processing Record 16 of Set 12 | dasoguz
# Processing Record 17 of Set 12 | papillion
# Processing Record 18 of Set 12 | sosnovo-ozerskoye
# Processing Record 19 of Set 12 | shieli
# Processing Record 20 of Set 12 | korla
# Processing Record 21 of Set 12 | linkou
# Processing Record 22 of Set 12 | pisco
# Processing Record 23 of Set 12 | mana
# Processing Record 24 of Set 12 | marsh harbour
# Processing Record 25 of Set 12 | port-gentil
# Processing Record 26 of Set 12 | shu
# Processing Record 27 of Set 12 | angra
# City not found. Skipping...
# Processing Record 28 of Set 12 | olafsvik
# Processing Record 29 of Set 12 | fenoarivo atsinanana
# Processing Record 30 of Set 12 | kinablangan
# Processing Record 31 of Set 12 | chicama
# Processing Record 32 of Set 12 | kamiichi
# Processing Record 33 of Set 12 | inhambane
# Processing Record 34 of Set 12 | brasilia
# Processing Record 35 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 12 | moscow
# Processing Record 37 of Set 12 | meadow lake
# Processing Record 38 of Set 12 | puerto madryn
# Processing Record 39 of Set 12 | astoria
# Processing Record 40 of Set 12 | vila franca do campo
# Processing Record 41 of Set 12 | dudinka
# Processing Record 42 of Set 12 | amahai
# Processing Record 43 of Set 12 | kakonko
# Processing Record 44 of Set 12 | lashio
# Processing Record 45 of Set 12 | valparaiso
# Processing Record 46 of Set 12 | oktyabrskiy
# Processing Record 47 of Set 12 | omsukchan
# Processing Record 48 of Set 12 | wadi musa
# Processing Record 49 of Set 12 | port blair
# Processing Record 50 of Set 12 | raseiniai
# Processing Record 1 of Set 13 | bonfim
# Processing Record 2 of Set 13 | antibes
# Processing Record 3 of Set 13 | dera bugti
# Processing Record 4 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 13 | murray bridge
# Processing Record 6 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 13 | kaili
# Processing Record 8 of Set 13 | slatina
# Processing Record 9 of Set 13 | shache
# Processing Record 10 of Set 13 | boende
# Processing Record 11 of Set 13 | hirara
# Processing Record 12 of Set 13 | warrington
# Processing Record 13 of Set 13 | sisimiut
# Processing Record 14 of Set 13 | yumen
# Processing Record 15 of Set 13 | tucumcari
# Processing Record 16 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 13 | hami
# Processing Record 18 of Set 13 | barrancabermeja
# Processing Record 19 of Set 13 | ixtapa
# Processing Record 20 of Set 13 | galesong
# Processing Record 21 of Set 13 | mingguang
# Processing Record 22 of Set 13 | grand-santi
# Processing Record 23 of Set 13 | meulaboh
# Processing Record 24 of Set 13 | acandi
# Processing Record 25 of Set 13 | kalianget
# Processing Record 26 of Set 13 | whitehorse
# Processing Record 27 of Set 13 | ilinge
# Processing Record 28 of Set 13 | manoel urbano
# Processing Record 29 of Set 13 | erenhot
# Processing Record 30 of Set 13 | killybegs
# Processing Record 31 of Set 13 | pochutla
# Processing Record 32 of Set 13 | mindelo
# Processing Record 33 of Set 13 | thunder bay
# Processing Record 34 of Set 13 | sembe
# Processing Record 35 of Set 13 | omboue
# Processing Record 36 of Set 13 | amapa
# Processing Record 37 of Set 13 | port augusta
# Processing Record 38 of Set 13 | nemuro
# Processing Record 39 of Set 13 | yangambi
# Processing Record 40 of Set 13 | kyren
# Processing Record 41 of Set 13 | andilamena
# Processing Record 42 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 13 | pinehurst
# Processing Record 44 of Set 13 | hammerfest
# Processing Record 45 of Set 13 | anadyr
# Processing Record 46 of Set 13 | grakhovo
# Processing Record 47 of Set 13 | baghmara
# Processing Record 48 of Set 13 | hasaki
# Processing Record 49 of Set 13 | gunjur
# Processing Record 50 of Set 13 | popondetta
# Processing Record 1 of Set 14 | lamar
# Processing Record 2 of Set 14 | kedrovyy
# Processing Record 3 of Set 14 | hofn
# Processing Record 4 of Set 14 | martapura
# Processing Record 5 of Set 14 | santarem
# Processing Record 6 of Set 14 | grand-couronne
# Processing Record 7 of Set 14 | yarmolyntsi
# Processing Record 8 of Set 14 | filingue
# Processing Record 9 of Set 14 | bereda
# Processing Record 10 of Set 14 | bilibino
# Processing Record 11 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 14 | corrientes
# Processing Record 13 of Set 14 | palmer
# Processing Record 14 of Set 14 | neiafu
# Processing Record 15 of Set 14 | khonsa
# Processing Record 16 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 14 | krasnoselkup
# Processing Record 18 of Set 14 | necochea
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | halifax
# Processing Record 21 of Set 14 | alofi
# Processing Record 22 of Set 14 | leh
# Processing Record 23 of Set 14 | oum hadjer
# Processing Record 24 of Set 14 | carandai
# Processing Record 25 of Set 14 | tuljapur
# Processing Record 26 of Set 14 | acajutla
# Processing Record 27 of Set 14 | carutapera
# Processing Record 28 of Set 14 | karauli
# Processing Record 29 of Set 14 | kapit
# Processing Record 30 of Set 14 | naftalan
# Processing Record 31 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 32 of Set 14 | honiara
# Processing Record 33 of Set 14 | helong
# Processing Record 34 of Set 14 | carballo
# Processing Record 35 of Set 14 | zaozerne
# Processing Record 36 of Set 14 | vrangel
# Processing Record 37 of Set 14 | oktyabrskoye
# Processing Record 38 of Set 14 | sangin
# Processing Record 39 of Set 14 | ruwi
# Processing Record 40 of Set 14 | siocon
# Processing Record 41 of Set 14 | partizanskoye
# Processing Record 42 of Set 14 | kinston
# Processing Record 43 of Set 14 | itoman
# Processing Record 44 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 45 of Set 14 | alamogordo
# Processing Record 46 of Set 14 | harbour breton
# Processing Record 47 of Set 14 | santiago de cuba
# Processing Record 48 of Set 14 | sokoto
# Processing Record 49 of Set 14 | alytus
# Processing Record 50 of Set 14 | jiangyou
# Processing Record 1 of Set 15 | aketi
# Processing Record 2 of Set 15 | okahandja
# Processing Record 3 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 4 of Set 15 | west richland
# Processing Record 5 of Set 15 | scarborough
# Processing Record 6 of Set 15 | auki
# Processing Record 7 of Set 15 | eureka
# Processing Record 8 of Set 15 | sao miguel do araguaia
# Processing Record 9 of Set 15 | porangatu
# Processing Record 10 of Set 15 | dauphin
# Processing Record 11 of Set 15 | mangrol
# Processing Record 12 of Set 15 | rio cuarto
# Processing Record 13 of Set 15 | colares
# Processing Record 14 of Set 15 | berbera
# Processing Record 15 of Set 15 | kanungu
# Processing Record 16 of Set 15 | vardo
# Processing Record 17 of Set 15 | craigieburn
# Processing Record 18 of Set 15 | wenling
# Processing Record 19 of Set 15 | aksarayskiy
# Processing Record 20 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 21 of Set 15 | havoysund
# Processing Record 22 of Set 15 | vilcun
# Processing Record 23 of Set 15 | yichang
# Processing Record 24 of Set 15 | buin
# Processing Record 25 of Set 15 | menongue
# Processing Record 26 of Set 15 | khuzhir
# Processing Record 27 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 15 | lensk
# Processing Record 29 of Set 15 | college
# Processing Record 30 of Set 15 | hove
# Processing Record 31 of Set 15 | yemtsa
# Processing Record 32 of Set 15 | bilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 675

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Jalu  29.0331   21.5482     73.89        38          88        4.34
# 1      Cayenne   4.9333  -52.3333     75.24       100          40        0.00
# 2      Ushuaia -54.8000  -68.3000     35.26        87          75        9.22
# 3  Yellowknife  62.4560 -114.3525     32.56        74         100       24.16
# 4   Mahibadhoo   3.7833   72.9667     81.43        79          91       20.98
# 5        Senno  59.5336   33.9167     42.51        89          99        7.27
# 6    Cape Town -33.9258   18.4232     65.91        85          75       11.50
# 7       Ambulu  -8.3450  113.6058     83.44        67         100        9.53
# 8         Lebu -37.6167  -73.6500     51.48        93          99        7.52
# 9   Sao Filipe  14.8961  -24.4956     79.03        80          87        6.08
#
#   Country Current Description
# 0      LY     overcast clouds
# 1      GF    scattered clouds
# 2      AR       broken clouds
# 3      CA          light snow
# 4      MV     overcast clouds
# 5      RU     overcast clouds
# 6      ZA       broken clouds
# 7      ID          light rain
# 8      CL     overcast clouds
# 9      CV          light rain

# %% [raw]
# # Display the DataFrame's column names using the columns Pandas function
# city_data_df.columns

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
city_data_df = city_data_df[new_columns_order]

# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Jalu      LY  29.0331   21.5482     73.89        38          88
# 1        Cayenne      GF   4.9333  -52.3333     75.24       100          40
# 2        Ushuaia      AR -54.8000  -68.3000     35.26        87          75
# 3    Yellowknife      CA  62.4560 -114.3525     32.56        74         100
# 4     Mahibadhoo      MV   3.7833   72.9667     81.43        79          91
# ..           ...     ...      ...       ...       ...       ...         ...
# 670        Lensk      RU  60.7253  114.9278     36.99        97         100
# 671      College      US  64.8569 -147.8028     26.55        90          75
# 672         Hove      GB  50.8309   -0.1672     57.56        79          99
# 673       Yemtsa      RU  63.0734   40.3329     43.43        82         100
# 674        Bilma      NE  18.6853   12.9164     86.94        15           0
#
#      Wind Speed Current Description
# 0          4.34     overcast clouds
# 1          0.00    scattered clouds
# 2          9.22       broken clouds
# 3         24.16          light snow
# 4         20.98     overcast clouds
# ..          ...                 ...
# 670        8.48          light rain
# 671        5.75          light snow
# 672        4.00     overcast clouds
# 673        7.25          light rain
# 674       11.01           clear sky
#
# [675 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
